# %% [markdown]
# ### How to program with Python and R in the same Jupyter notebook
#
# This is within the R kernel so I can just do R commands without using R magic (i.e., without beginning each command with %R)

# %%
a <- rnorm(100)

# %%
plot(a)
# Out:
# plot without title

# %% [markdown]
# fuck yes
